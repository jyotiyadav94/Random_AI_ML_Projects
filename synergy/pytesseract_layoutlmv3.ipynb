# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.7/dist-packages (0.3.9)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->pytesseract) (3.0.9)

# %%
import numpy as np
import pytesseract
from PIL import Image
import pandas as pd

# %%
path = '/content/un_speckle (2).png'

sample = pytesseract.image_to_data(path, output_type='data.frame')
sample
# Out:
#      level  page_num  block_num  par_num  line_num  word_num  left   top  \
# 0        1         1          0        0         0         0     0     0
# 1        2         1          1        0         0         0   365    19
# 2        3         1          1        1         0         0   365    19
# 3        4         1          1        1         1         0   365    19
# 4        5         1          1        1         1         1   365    19
# ..     ...       ...        ...      ...       ...       ...   ...   ...
# 371      4         1         47        1         1         0    51  1102
# 372      5         1         47        1         1         1    51  1102
# 373      5         1         47        1         1         2    76  1102
# 374      5         1         47        1         1         3    85  1102
# 375      5         1         47        1         1         4   683  1102
#
#      width  height  conf        text
# 0      794    1123    -1         NaN
# 1       51      21    -1         NaN
# 2       51      21    -1         NaN
# 3       51      21    -1         NaN
# 4       51      21     5           >
# ..     ...     ...   ...         ...
# 371    684      10    -1         NaN
# 372     21      10    30        Pag.
# 373      4       8    30           1
# 374     17       8    56         di2
# 375     52       8     0  ‘7iozr2022
#
# [376 rows x 12 columns]

# %%
# sample[100:150]

# %%
# sample.to_csv('1.csv', index=False)

# %%
text = pytesseract.image_to_string(Image.open('un_speckle (2).png'))
print(text)
# Out:
# >
#
# EUROCORPORATION
#
#
#
# PER AUTISTA PER UFFICIO
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘AUTOTAPPEZZERIA BENACCI S.N.C. DI MICHELE E ‘AUTOTAPPEZZERIA BENACCI S.N.C. DI MICHEL
# ee MATTEO BENACCI ao E MATTEO BENACCI
# Unit. Loc. FIRENZE - VIA LIVORNO 8/50 Operatore Matilde De Martino - Mob. 346 7841762
# Referente | MICHELE BENACCI CFProduttore | 06601660480
# Telefono 348 7215986 Email Cliente __ | info@autotappezzeriabenacci.it
# Data Richiesta 17/02/2022 | Orario richiesta 08:30 Email Produttore | michele@autotappezzeriabenacci.it
# am
# Mattina [Dalle 08:30 [Alle PER LA LOGISTICA:
# Pomeriggio | Dalle Alle 18:00 CCHIAMARE UN GIORNO PRIMA PER CONFERMA DATA E ORARIO
#
# MEZZO SCARRABILINO O SPONDA 4 PP -> CARICA IL CLENTE
# RICHIESTO PER LUNEDi 21.02.2022 0 MARTEDi 22.02.2022
# https://www.google.com/maps/@43.7712392,11.1954905,3a,75y
# ,314.18h,75.22t/data=!3m6!1e1!3m4!
# ‘Ls4hSRjkpxpkWzie€2hNtxwg!2e0!7i1638418i8192
#
# Tipologia rifluto
#
# CER DESCRIZIONE SF ‘ADR
#
#
#
#
#
#
#
#
#
# 040222 Rifiuti da fibre tessililavorate Solido non pulverulento
#
#
#
# Classe Pericolo: Destino: [R13
# Confezionamento: | 10 SACCHI
# Destinazion« EUROCORPORATION
#
#
#
#
#
#
#
#
#
# 150106 Imballaggi misti Solido non pulverulento
#
#
#
#
#
#
#
#
#
# Classe Pericolo: Destino: [R13
# Confezionamento: | 5/6 SACCHI
# Destinazion« EUROCORPORATION
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# EUROCORPORATION 5... CF. - Piva 05235640488 .E.A. 521452 Captale Sociale € 100,000,000
# Via de’ Cottani 178 - 50145 Firenze | Tel. 055 7222419 Fax 055 7227520
# Info@eurecorporationit | info@pec.eurocorporation.t | www.eurecorporationit
#
# Pag. 1 di2 ‘7iozr2022
